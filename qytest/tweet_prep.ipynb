# %%
import pandas as pd
import numpy as np
import os
import nltk

# %%
# df = pd.read_csv("tweets.csv", on_bad_lines='skip')
df = pd.read_csv("tweets.csv")
df
# Out:
#                 id                                               text  \
# 0       1.0197E+18  VIDEO: “I was in my office. I was minding my o...
# 1      1.01971E+18  The price of lumber $LB_F is down 22% since hi...
# 2      1.01971E+18  Who says the American Dream is dead? https://t...
# 3      1.01972E+18  Barry Silbert is extremely optimistic on bitco...
# 4      1.01972E+18  How satellites avoid attacks and space junk wh...
# ...            ...                                                ...
# 28423  1.01973E+18         $FB : 29234a9c-7f08-4d5a-985f-cb1a5554ecf9
# 28424  1.01973E+18  【仮想通貨】ビットコインの価格上昇、８０万円台回復　約１カ月半ぶり　　　　　　$BTC ht...
# 28425  1.01973E+18  RT @invest_in_hd: 'Nuff said!  $TEL #telcoin #...
# 28426  1.01973E+18  【仮想通貨】ビットコインの価格上昇、８０万円台回復　約１カ月半ぶり　　　　　　$BTC ht...
# 28427  1.01973E+18  Stellar $XLM price: $0.297852 Binance registra...
#
#                             timestamp           source symbols  \
# ...
